# %%
from datasets import Dataset
import os

def load_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Load your Punjabi text files
STATIC="static/"
file_paths = [STATIC+i for i in os.listdir(STATIC)]
texts = [load_data(file) for file in file_paths]

# Combine all texts into one large text
combined_text = " ".join(texts)

# Create a dataset with the entire text (you might need to preprocess or split it manually)
dataset = Dataset.from_dict({"text": [combined_text]})

# %%
dataset["text"]
# Out:
# ['ਸੰਤਰੇ, ਮਾਲਟੇ ਤੇ ਨਿੰਬੂ\n\nਵੀਹ ਸਾਲ ਦੀ ਲੰਬੀ ਸਮੀਖਿਆ ਤੋਂ ਬਾਅਦ ਇਸ ਨੂੰ 1935 ਵਿੱਚ ਇੱਕ ਨਵੀ ਕਿਸਮ\n\'ਜੋਂ ਵਪਾਰਿਕ ਖੇਤੀ ਲਈ ਪਰਵਾਨ ਕੀਤਾ ਗਿਆ। ਗੁ\n\nਵਿਚਕਾਰ ਪ੍ਰਗਟ ਹੁੰਦੇ ਹਨ ਅਤੇ ਇਸ ਦਾ ਛਿਲਕਾ ਨਾ ਤਾਂ ਢਿੱਲਾ ਤੇ ਨਾ ਹੀ ਬਹੁਤ ਸਖਤ\nਹੁੰਦਾ ਹੈ। ਪੰਜਾਬ ਐਗਰੀਕਲਚਰਲ ਯੂਨੀਵਰਸਿਟੀ ਦੇ ਖੇਤਰੀ ਫ਼ਲ ਕੋਜ ਕੇਂਦਰ, ਅਬੋਹਰ\nਵਿਖੇ ਕਿੰਨੂ ਦੀ ਲਗਾਤਾਰ ਸਮੀਖਿਆ ਤੋਂ ਬਾਅਦ, 1968 ਵਿੱਚ ਇਸ ਦੀ ਵਪਾਰਿਕ ਖੇਤੀ\nਤੀ ਸਿਫ਼ਾਰਿਸ਼ ਕੀਤੀ ਗਈ। ਉਸ ਤੋਂ ਬਾਅਦ ਕਿੰਨੂ ਰਕਬੇ ਤੇ ਉਪਜ ਪੱਖੋਂ ਪਹਿਲੇ ਦਰਜੇ\n” ਫ਼ਲ ਬਣ ਗਿਆ ਹੈ ਅਤੇ ਇਸ ਨੇ ਪੰਜਾਬ ਵਿੱਚ ਸੁਨਿਹਰੀ ਕ੍ਰਾਂਤੀ ਨੂੰ ਜਨਮ ਦਿੱਤਾ।\n\n੨\n\nਨਵੀਆਂ ਕਿਸਮਾਂ ਦੇ ਆਉਣ ਦੇ ਨਾਲ ਅਤੇ ਨਿੰਬੂ-ਜਾਤੀ ਦੀਆਂ ਅਗੇਤਰੀ\nਕਿ\n੍\n\n੩੨੧\n\nਤ਼\nਪਛੇਤਰੀ ਕਿਸਮਾਂ ਦੀ ਸਿਫ਼ਾਰਿਸ਼ ਸਦਕਾਂ ਨਿੰਬੂ-ਜਾਤੀ ਉਦਯੋਗ ਵਿੱਚ ਹੋਰ ਧਾ ਹੋਇਆ\nਹੈ। ਪ੍ਰਤੀ ਇਕਾਈ ਵਧੇਰੇ ਆਮਦਨ ਲਈ ਕਿਸਾਨਾਂ ਨੂੰ ਵਧੀਆ ਕਿਸਮ ਦੇ ਬੂਟੇ ਲਾਉਣੇ\nਹਨ ਅਤੇ ਖਾਦਾਂ, ਕੀਟ-ਨਾਸ਼ਕਾਂ, ਰੋਗ ਨਾਸ਼ਕਾਂ, ਮਸ਼ੀਨਰੀ ਤੇ ਡੱਬੇ-ਬੰਦੀ ਦੇ\nਦੀ ਵਰਤੋਂ ਬੜੇ ਸੁਚੱਜੇ ਢੰਗ ਨਾਲ ਕਰਨੀ ਚਾਹੀਦੀ ਹੈ। ਇਸ ਫ਼ਸਲ ਦੇ ਲਗਾਤਾਰ\nਰਣ ਉਤਪਾਦਨ ਲਈ ਚੰਗੇ ਪ੍ਰਬੰਧਾਂ ਨੂੰ ਅਪਨਾਉਣ ਦੀ ਸਖਤ ਲੋੜ ਹੈ ਅਤੇ ਰੋਗ\nਆਂ `ਤੇ ਚੰਗੀ ਤਰ੍ਹਾਂ ਨਿਰੰਤ੍ਣ ਜਰੂਰੀ ਹੈ। ਨਿੰਬੂ-ਜਾਤੀ ਦੇ ਉਤਪਾਦਨਾਂ ਦੀਆਂ\nਨੂੰ ਸਹੀ ਢੰਗ ਨਾਲ ਹੱਲ ਕਰਨਾ ਜ਼ਰੂਰੀ ਹੈ। ਇਹ ਈ-ਪੁਸਤਕ\n_ਨਾਲ ਲਿਖੀ ਗਈ ਹੈ ਤਾਂ ਜੋ ਨਿੰਬੂ-ਜਾਤੀ ਦੀ ਖੇਤੀ ਨੂੰ ਬਿਹਤਰ ਬਣਾਇਆ\n\nਅਤੇ ਨਿੰਬੂ-ਜਾਤੀ ਦੇ ਉਤਪਾਦਕਾਂ ਦੀਆਂ ਮੁਸ਼ਕਿਲਾਂ ਨੂੰ ਸੁਲਝਾਇਆ ਜਾ ਸਕੇ।\n\n[”\n\nਹੁ\n੨੮\nਜੰ\n\nਹਰ ਤੂ\n“3\n\n| ਘ੬\n\nਲੀ ਜ਼ ੭੦\nਤੇ ਤਹ\nਡਰ &\n\nਜ੭ ੨, `\n&\nਇਿ\n\nਤਰ\n੨]\n\nਮਿੱਟੀ ਤੇ ਪੌਣ-ਪਾਣੀ\n\nਵਿ ੧\n\nਵੱਧ ਤੋਂ ਵੱਧ ਉਪਜ ਨੂੰ ਨਿਸ਼ਚਿਤ ਕਰਨ ਲਈ ਸਹੀ ਜਗ੍ਹਾ ਤੇ ਜ਼ਮੀਨ ਦੀ ਚੋਣ\nਧਿਆਨ ਨਾਲ ਕੀਤੀ ਜਾਣੀ ਚਾਹੀਦੀ ਹੈ। ਇਸ ਤੋਂ ਇ\nਕਿ\n\nਲਾਵਾ ਫ਼ਲਾਂ ਦਾ ਬਾਗ ਸਥਾਪਿਤ\nਹੁੰਦਾ ਹੈ ਅਤੇ ਇਸ ਲਈ ਯੋਜਨਾ ਬੜੇ ਧਿਆਨ ਨਾਲ\nਟੀ ਦੀਆਂ ਲੋੜਾਂ ਬਹੁਤ ਢੁੱਕਵੀਆਂ ਹੋਣੀਆਂ\nਚਾਹੀਦੀਆਂ ਹਨ ਅਤੇ ਇਹ ਹਾ ਨਹੀ ਜਿਹੜੀ ਮਿੱਟੀ ਆਮ ਫ਼ਸਲਾਂ ਉਗਾਉਣ ਲ\n੪੨ ੩੩ ੨ ੨ ੨੭ ੨ ੨੩੭ %%9- ੪੬\nਚੰਗੀ ਹੋਵੇ ਉਹ ਨਿੰਬੂ-ਜਾਤੀ ਲਈ ਕਿ ਹੇਠਲੀ ਮਿੱਟੀ ਵਿੱਚ ਕ\nਅਯੋਗ ਹਾਲਤਾਂ ਹੋ ਸਕਦੀਆਂ ਹਨ। ਇਸ ਲ ਜ਼ੋਰ ਸਲਾਹ ਦਿੱਤੀ ਜਾਂਦੀ ਹੈ ਕਿ\nਨਿੰਬੂ-ਜਾਤੀ ਦਾ ਬਾਗ ਲਾਉਣ ਤੋਂ ਪਹਿਲਾ ਮਿੱ ਪਾਦਨ ਦੀ ਯੋਗਤਾ ਲਈ ਪਰਖ\nਲੈਣਾ ਚਾਹੀਦਾ ਹੈ। ਇਸ ਮੰਤਵ ਲ ; ਥਾਵਾਂ ਦੀ ਭੌਤਿਕ ਤੇ ਰਸਾਇਣਨ\n੧ ੨੨੪ ੩ ੧੦ ੜੇ\nਗੁਣਾਂ ਲਈ ਪਰਖ ਕਰ ਲੈਣੀ ਚਾਹੀਦੀ ਹੈ।\n\n੭\n\nਯੂ ਪੂ ਹਕ\n\n੨\nਊਂ\n\n੭ ੨੧\n0\n\n-ਜਾਤੀ ਦੇ ਰੁੱਖ ਮਿੱਟੀ ਵਿੱਚ ਲੂਣ ਦੇ ਬਹੁਤ ਜ਼ਿਆਦਾ ਇਕੱਠ ਪ੍ਤੀ ਬੜੇ\nਹੁੰਦੇ ਹਨ। ਮਿੱਟੀ ਦੀ ਬਣਤਰ ਨੂੰ ਸਖਤ ਤਹਿ ਦੀ ਹੋਂਦ, ਪੱਥਰ ਜਾਂ ਚੂਨੇ ਦੀ\n\nਧਿਆਨ ਨਾਲ ਪਰਖ ਲੈਣਾ ਚਾਹੀਦਾ ਹੈ। ਅਜਿਹੀਆਂ ਹਾਲਤਾਂ ਵਿੱਚ ਪੌਦਾ\n\n੨ ੧੪੩\n\nਪਾਣੀ ਤੇ ਖੁਰਾਕੀ ਤੱਤ ਜਜ਼ਬ ਨਹੀਂ ਕਰ ਸਕਦਾ ਅਤੇ ਸਿੱਟੇ ਵਜੋਂ ਪੌਦੇ ਦਾ\nਜਾਂਦਾ ਹੈ। ਮਿੱਟੀ ਵਿੱਚ ਕੈਲਸ਼ੀਅਮ ਕਾਰਬੋਨੇਟ ਦੀ ਬਹੁਤੀ ਮਾਤਰਾ ਪੌਦੇ\nਵੇਂ ਕਿ ਫ਼ਾਸਫ਼ੋਰਸ, ਜਿੰਕ, ਮੈਗਨੀਜ਼ੀਅਮ, ਲੋਹਾ ਤੇ ਤਾਂਬੇ\nਜਾ ੪ 9੬ ਤਕ ਤਜ ਤੇ\n\nਤੋਂ ਇਲਾਵਾ, ਮਿੱਟੀ ਵਿੱਚ ਤੇਜ਼ਾਬੀ ਜਾਂ ਖਾਰੇ ਤੱਤਾਂ ਦਾ\nਨੂੰ ਧਿਆਨ ਵਿੱਚ ਰੱਖਣਾ ਜਰੂਰੀ ਹੈ। ਪੌਦੇ ਦੇ ਵਿਕਾਸ\n\nਪ੍ਰਾਪਤੀ ਦਾ ਨੇ ਨੇੜਲਾ ਸਬੰਧ ਮਿੱਟੀ ਦੀ ਚ, ਨਾਲ ਹੁੰਦਾ\n\nਲਿਵ\n[੭\n\n|\n\n23\n\nਤ\nਹੀ\nਗੀ\nਜ ੩\n\nਰੰ ਹਉ 2 ਟ\n\nਹਾਂ\n੩\n: &.\n\n੭ % 36 <੭\nਡੇ\n]\n੫\n\n੨\n॥੦੧\n\n੩\nਛੱਤ\n\n੨੩\n\n੩\n\nਘ\n\nਪਰ\n\n੩ ਤੇ ਘਰ\n6; ੨]\n|\n\nਹੂ\nਸਿ\n27\nਲਹ\nਟਰ\nਰੱ\n੨\n9੭\n” ੭\n/ “ਜਾ\n” ਗੋ”\nਗਰ\n” ੨੩\n\n! ਨ੍ਰ\n(੫੭\n\nਜੇ\nਲਤ\n7\nਉਰ: ”\nਗੰ\n|\n੦];\n(7\n\n\'ਚ ਥੋੜ੍ਹਾ ਜਿਹਾ ਤੇਜ਼ਾਬੀ ਅ ਅਸਰ ਹੁੰਦਾ ਹੈ ਅਤੇ ਜਿਨ੍ਹਾਂ ` ਦੀ ਪੀ. ਐਚ. ਸੀਮਾ\nਹੁੰਦੀ ਹੈ ਹੈ। ਅਜਿਹੀਆਂ ਹਾਲਤਾਂ ਵਿੱਚ ਬਹੁਤ ਸਾਰੇ ਖੁਰਾਕੀ ਤੱਤ ਪੌਦੇ ਨੂੰ ਛੇਤੀ\n\nਹਸ\n੨੧\n੨੧\n\nਡੀ\nਪੀ\n\n੨\n੫੨;\n0੨੧ ”\n\nਹੀ ਮਿਲ ਜਾਂਦੇ ਹਨ। ਜਿਥੋਂ ਤੱਕ ਸੰਭਵ ਹੋਵੇ ਪੱਧਰੀ ਜ਼ਮੀਨ ਦੀ ਚੋਣ ਕਰਨੀ ਚਹੀਦੀ ਹੈ\nਅਤੇ ਦੋ ਮੀਟਰ ਥੱਲੇ ਕੋਈ ਸਖਤ ਤਹਿ ਨਹੀਂ ਹੋਣੀ ਚਾਹੀਦੀ।\n\nਸਿੱਲ੍ਹੀਆਂ ਜ਼ਮੀਨਾਂ ਦੇ ਪਾਣੀ ਦੇ ਪੱਧਰ ਦੇ ਜ਼ਿਆਦਾ ਚੜ੍ਹਦੇ-ਉਤਰਦੇ ਹਾਲਾਤ\nਉ\n\nਲੀਆਂ ਜ਼ਮੀਨਾਂ ਨੂੰ ਨਿੰਬੂ-ਜਾਤੀ ਦੇ ਉਤਪਾਦਨ ਲਈ ਨਹੀ ਚੁਣਨਾ ਚਾਹੀਦਾ। ਇਹੋ\n\nਜਿਹੇ ਹਾਲਾਤ ਜੜ੍ਹ ਦੇ ਗਾਲੇ ਲਈ ਜ਼ਿਮੇਵਾਰ ਹੁੰਦੇ ਹਨ ਜਿਸ ਨਾਲ ਪੌਦਾ ਅੰਤ ਵਿੱਚ ਮਰ\n\nਜਾਂਦਾ ਹੈ। ਇਸੇ ਤਰ੍ਹਾਂ ਜਿਨ੍ਹਾਂ ਜ਼ਮੀਨਾਂ ਵਿੱਚ ਉੱਪਰਲੇ ਤਲ ਤੋਂ ਪਾਣੀ ਦਾ ਨਿਕਾਸ ਠੀਕ\nਸਾ\n\nਨਾ ਹੋਵੇ ਉਨ੍ਹਾਂ ਦੀ ਚੋਣ ਨਹੀਂ ਕਰਨੀ ਚਾਹੀਦੀ। ਨਿੰਬੂ-ਜਾਤੀ ਦੇ ਬਾਗ ਅਜਿਹੇ ਖੇਤਰਾਂ\nਵਿੱਚ ਨਹੀ ਲਗਾਉਣੇ ਚਾਹੀਦੇ ਜਿੱਥੇ ਪਾਣੀ ਕਈ ਦਿਨ ਖੜ੍ਹਾ ਰਹੇ ਅਤੇ ਜਿੱਥੇ ਹੜ੍ਹ ਦਾ\nਪਾਣੀ ਆ ਜਾਵੇ। ਪਾਣੀ ਦੇ ਚੰਗੇ ਨਿਕਾਸ ਵਾਲੀ ਉਪਜਾਊ ਰੇਤਲੀ-ਮੈਰਾ ਮਿੱਟੀ ਜਿਸ ਦੀ\nਪੀ.ਐਚ. 8.5 ਤੱਕ ਹੋਵੇ, ਜਿਸ ਦੀ ਬਿਜਲਾਈ-ਅਨੁਰੂਪਤਾ 0.5 ਮਿਲੀ ਮਹੋਸ/ਸੈਂ.ਮੀ.\n੨੩ €ਸ ੦ ੩੪ ਝ੩੭ <੪ €% ੪੨ ਬੜ ਯ ਵਿ\n\nਹੋਵੇ, ਜਿਸ ਵਿੱਚ ਕੈਲਸ਼ੀਅਮ ਕਾਰਬੋਨੇਟ 5% ਤੱਕ ਹੋਵੇ, ਜਿਸ ਵਿੱਚ ਚੂਨੇ ਦਾ ਇਕੱਠ\n10% ਤੱਕ ਹੋਵੇ ਅਤੇ ਜਿਹੜੀ ਹੇਠਲੀ ਸਖਤ ਤਹਿ ਤੋਂ ਮੁਕਤ ਹੋਵੇ, ਨਿੰਬੂ-ਜਾਤੀ ਦੀ ਉਪਜ\n\nਲਈ ਬਹੁਤ ਢੁੱਕਵੀ\' ਹੁੰਦੀ ਹੈ।\n\nਬਹੁਤ ਗਰਮੀ ਤੇ ਬਹੁਤ ਸਰਦੀ ਨਿੰਬੂ- ਜਾਤੀ ਦੇ ਉਤਪਾਦਨ ਲਈ ਉਚਿੱਤ ਨਹੀ\n\nਹੁੰਦੀ। ਇਹ ਵੇਖਿਆ ਗਿਆ ਹੈ ਕਿ -2 ਤੋਂ 0 ਡਿਗਰੀ ਸੈਲਸੀਅਸ ਦੇ ਤਾਪਮਾਨ ਵਿੱਚ\n\nਨਿੰਬੂ-ਜਾਤੀ ਦੇ ਪੌਦਿਆਂ ਨੂੰ ਨੁਕਸਾਨ ਹੁੰਦਾ ਹੈ। ਖਾਸ ਕਰ ਕੇ ਜੇ ਅਜਿਹੇ ਥੋੜ੍ਹੇ ਤਾਪਮਾਨ\nਲੇ ਸਮੇਂ ਲੰਬੇ ਹੋ ਜਾਣ। ਡੀ ਜਿ\n\nਇਸ ਤਰ੍ਹਾਂ ਦਾ ਨੁਕਸਾਨ ਹੋਰ ਵੀ ਜਿਆਦਾ ਹੋ ਜਾਂਦਾ ਹੈ ਜ ...

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, TrainingArguments, Trainer

# Load the pre-trained model and tokenizer
model_name = "xlm-roberta-base"  # You can use 'bert-base-multilingual-cased' as well
tokenizer = AutoTokenizer.from_pretrained(model_name)

def preprocess_function(examples):
    questions = examples["text"]  # Use the same text for questions as this is unsupervised
    inputs = tokenizer(questions, padding="max_length", truncation=True, return_tensors="pt")
    return inputs

tokenized_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/gy/8qpd69gd0351rv2j6zldznmr0000gp/T/ipykernel_1017/2719000475.py", line 1, in <module>
#     from transformers import AutoTokenizer, AutoModelForQuestionAnswering, TrainingArguments, Trainer
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/transformers/__init__.py", line 26, in <module>
#     from . import dependency_versions_check
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/transformers/dependency_versions_check.py", line 16, in <module>
#     from .utils.versions import require_version, require_version_core
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/transformers/utils/__init__.py", line 34, in <module>
#     from .generic import (
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/transformers/utils/generic.py", line 462, in <module>
#     import torch.utils._pytree as _torch_pytree
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 12
#       9     inputs = tokenizer(questions, padding="max_length", truncation=True, return_tensors="pt")
#      10     return inputs
# ---> 12 tokenized_dataset = dataset.map(preprocess_function, batched=True)
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/datasets/arrow_dataset.py:602, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     600     self: "Dataset" = kwargs.pop("self")
#     601 # apply actual function
# --> 602 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     603 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     604 for dataset in datasets:
#     605     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/datasets/arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/datasets/arrow_dataset.py:3167, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3161 if transformed_dataset is None:
#    3162     with hf_tqdm(
#    3163         unit=" examples",
#    3164         total=pbar_total,
#    3165         desc=desc or "Map",
#    3166     ) as pbar:
# -> 3167         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3168             if done:
#    3169                 shards_done += 1
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/datasets/arrow_dataset.py:3581, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3579         writer.write_table(batch.to_arrow())
#    3580     else:
# -> 3581         writer.write_batch(batch)
#    3582 num_examples_progress_update += num_examples_in_batch
#    3583 if time.time() > _time + config.PBAR_REFRESH_TIME_INTERVAL:
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/datasets/arrow_writer.py:568, in ArrowWriter.write_batch(self, batch_examples, writer_batch_size)
#     566         col_try_type = try_features[col] if try_features is not None and col in try_features else None
#     567         typed_sequence = OptimizedTypedSequence(col_values, type=col_type, try_type=col_try_type, col=col)
# --> 568         arrays.append(pa.array(typed_sequence))
#     569         inferred_features[col] = typed_sequence.get_inferred_type()
#     570 schema = inferred_features.arrow_schema if self.pa_writer is None else self.schema
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/pyarrow/array.pxi:248, in pyarrow.lib.array()
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/pyarrow/array.pxi:112, in pyarrow.lib._handle_arrow_array_protocol()
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/datasets/arrow_writer.py:193, in TypedSequence.__arrow_array__(self, type)
#     191 else:
#     192     trying_cast_to_python_objects = True
# --> 193     out = pa.array(cast_to_python_objects(data, only_1d_for_numpy=True))
#     194 # use smaller integer precisions if possible
#     195 if self.trying_int_optimization:
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/datasets/features/features.py:455, in cast_to_python_objects(obj, only_1d_for_numpy, optimize_list_casting)
#     435 def cast_to_python_objects(obj: Any, only_1d_for_numpy=False, optimize_list_casting=True) -> Any:
#     436     """
#     437     Cast numpy/pytorch/tensorflow/pandas objects to python lists.
#     438     It works recursively.
#    (...)
#     453         casted_obj: the casted object
#     454     """
# --> 455     return _cast_to_python_objects(
#     456         obj, only_1d_for_numpy=only_1d_for_numpy, optimize_list_casting=optimize_list_casting
#     457     )[0]
#
# File ~/miniconda3/envs/ocr/lib/python3.10/site-packages/datasets/features/features.py:332, in _cast_to_python_objects(obj, only_1d_for_numpy, optimize_list_casting)
#     325         return obj.detach().cpu().numpy(), True
#     326     else:
#     327         return (
#     328             [
#     329                 _cast_to_python_objects(
#     330                     x, only_1d_for_numpy=only_1d_for_numpy, optimize_list_casting=optimize_list_casting
#     331                 )[0]
# --> 332                 for x in obj.detach().cpu().numpy()
#     333             ],
#     334             True,
#     335         )
#     336 elif config.TF_AVAILABLE and "tensorflow" in sys.modules and isinstance(obj, tf.Tensor):
#     337     if obj.ndim == 0:
#
# RuntimeError: Numpy is not available
