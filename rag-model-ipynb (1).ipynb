# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Load the data
file_path = "/kaggle/input/punjabi-text/static/1.txt"  # Update with the actual path to your file in Google Drive
with open(file_path, 'r', encoding='utf-8') as file:
    punjabi_text = file.read()

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Simple heuristic-based tokenizer for Punjabi text
def punjabi_sent_tokenize(text):
    sentences = text.split('।')  # Use the appropriate sentence delimiter
    return [sentence.strip() for sentence in sentences if sentence]

# Apply the custom tokenizer
sentences = punjabi_sent_tokenize(punjabi_text)

print(sentences[:5])  # Print the first few tokenized sentences
# Out:
# ["ਦੀ ਨਿਗਰਾਨੀ ਹੇਠ ਤਿਆਰ ਕੀਤਾ ਗਿਆ\n\n“ਸਬਜ਼ੀਆਂ ਦੀ ਕਾਸ਼ਤ ਲਈ ਸਿਫ਼ਾਰਸ਼ਾਂ-2021', ਦੀ ਕਿਤਾਬ ਨਿਰਦੇਸ਼ਕ\nਖੋਜ, ਪੰਜਾਬ ਐਗਰੀਕਲਚਰਲ ਯੂਨੀਵਰਸਿਟੀ, ਲੁਧਿਆਣਾ ਦੀ ਸਹਾਇਤਾ ਨਾਲ ਵੱਖ-\nਵੱਖ ਵਿਭਾਗਾਂ ਦੇ ਮਾਹਿਰਾਂ ਦੁਆਰਾ ਪ੍ਰਵਾਣਿਤ ਸਿਫ਼ਾਰਸ਼ਾਂ ਅਨੁਸਾਰ ਤਿਆਰ ਕੀਤੀ ਗਈ\nਹੈ", "ਇਸ ਪੁਸਤਕ ਵਿੱਚ ਸਬਜ਼ੀਆਂ ਦਾ ਵਧੇਰੇ ਝਾੜ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ 7 ਜਨਵਰੀ\n2021 (ਸਰਦੀਆਂ) ਅਤੇ 6 ਜੁਲਾਈ 2021 (ਗਰਮੀਆਂ) ਨੂੰ 'ਖੋਜ ਵਿਗਿਆਨੀਆਂ ਅਤੇ\nਪਸਾਰ ਮਾਹਿਰਾਂ ਦੀ ਬਾਗਬਾਨੀ ਦੇ ਵਰਚੁਅਲ ਵਰਕਸ਼ਾਪਾਂ` ਦੌਰਾਨ ਵਿਚਾਰੇ ਗਏ ਨਵੇ\nਢੰਗਾਂ ਦਾ ਵੇਰਵਾ ਦਿੱਤਾ ਗਿਆ ਹੈ", 'ਇਹ ਕਿਤਾਬ ਬਹੁਤ ਸਰਲ ਤੇ ਸਾਦੀ ਭਾਸ਼ਾ ਵਿੱਚ\nਲਿਖੀ ਗਈ ਹੈ ਤਾਂ ਕਿ ਪੰਜਾਬ ਦੇ ਕਿਸਾਨ ਅਤੇ ਪਸਾਰ ਸਿੱਖਿਆ ਕਾਮੇ ਇਸ ਤੋਂ ਵੱਧ ਤੋਂ\nਵੱਧ ਲਾਭ ਉਠਾ ਸਕਣ', '15੩੧4 978-81-932778-9-8\n\nਕੀਮਤ : 50 ਰੁਪਏ\n\nਇਹ ਕਿਤਾਬ ਕਾਪੀ ਰਾਈਟ ਸੁਰੱਖਿਅਤ ਹੈ', 'ਪੁਕਾਸ਼ਕ/ਸੰਪਾਦਕ ਦੀ ਪ੍ਰਵਾਨਗੀ\nਬਿਨਾਂ ਪ੍ਰਕਾਸ਼ਤ ਕਰਨ ਦੀ ਆਗਿਆ ਨਹੀਂ ਹੈ']

# %%
# !pip install indic-nlp-library
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 15.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from indicnlp.tokenize.sentence_tokenize import sentence_split

# Apply the sentence tokenizer from Indic NLP
sentences = sentence_split(punjabi_text, lang='pa')  # 'pa' is the language code for Punjabi

print(sentences[:5])  # Print the first few tokenized sentences
# Out:
# ["ਦੀ ਨਿਗਰਾਨੀ ਹੇਠ ਤਿਆਰ ਕੀਤਾ ਗਿਆ\n\n“ਸਬਜ਼ੀਆਂ ਦੀ ਕਾਸ਼ਤ ਲਈ ਸਿਫ਼ਾਰਸ਼ਾਂ-2021', ਦੀ ਕਿਤਾਬ ਨਿਰਦੇਸ਼ਕ\nਖੋਜ, ਪੰਜਾਬ ਐਗਰੀਕਲਚਰਲ ਯੂਨੀਵਰਸਿਟੀ, ਲੁਧਿਆਣਾ ਦੀ ਸਹਾਇਤਾ ਨਾਲ ਵੱਖ-\nਵੱਖ ਵਿਭਾਗਾਂ ਦੇ ਮਾਹਿਰਾਂ ਦੁਆਰਾ ਪ੍ਰਵਾਣਿਤ ਸਿਫ਼ਾਰਸ਼ਾਂ ਅਨੁਸਾਰ ਤਿਆਰ ਕੀਤੀ ਗਈ\nਹੈ।", "ਇਸ ਪੁਸਤਕ ਵਿੱਚ ਸਬਜ਼ੀਆਂ ਦਾ ਵਧੇਰੇ ਝਾੜ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ 7 ਜਨਵਰੀ\n2021 (ਸਰਦੀਆਂ) ਅਤੇ 6 ਜੁਲਾਈ 2021 (ਗਰਮੀਆਂ) ਨੂੰ 'ਖੋਜ ਵਿਗਿਆਨੀਆਂ ਅਤੇ\nਪਸਾਰ ਮਾਹਿਰਾਂ ਦੀ ਬਾਗਬਾਨੀ ਦੇ ਵਰਚੁਅਲ ਵਰਕਸ਼ਾਪਾਂ` ਦੌਰਾਨ ਵਿਚਾਰੇ ਗਏ ਨਵੇ\nਢੰਗਾਂ ਦਾ ਵੇਰਵਾ ਦਿੱਤਾ ਗਿਆ ਹੈ।", 'ਇਹ ਕਿਤਾਬ ਬਹੁਤ ਸਰਲ ਤੇ ਸਾਦੀ ਭਾਸ਼ਾ ਵਿੱਚ\nਲਿਖੀ ਗਈ ਹੈ ਤਾਂ ਕਿ ਪੰਜਾਬ ਦੇ ਕਿਸਾਨ ਅਤੇ ਪਸਾਰ ਸਿੱਖਿਆ ਕਾਮੇ ਇਸ ਤੋਂ ਵੱਧ ਤੋਂ\nਵੱਧ ਲਾਭ ਉਠਾ ਸਕਣ।', '15੩੧4 978-81-932778-9-8\n\nਕੀਮਤ : 50 ਰੁਪਏ\n\nਇਹ ਕਿਤਾਬ ਕਾਪੀ ਰਾਈਟ ਸੁਰੱਖਿਅਤ ਹੈ ।', 'ਪੁਕਾਸ਼ਕ/ਸੰਪਾਦਕ ਦੀ ਪ੍ਰਵਾਨਗੀ\nਬਿਨਾਂ ਪ੍ਰਕਾਸ਼ਤ ਕਰਨ ਦੀ ਆਗਿਆ ਨਹੀਂ ਹੈ ।']

# %%
import re

def preprocess_punjabi_text(sentences):
    preprocessed_sentences = []
    for sentence in sentences:
        # Remove unwanted characters like newlines and multiple spaces
        sentence = re.sub(r'\s+', ' ', sentence)  # Replace multiple spaces/newlines with a single space
        sentence = sentence.replace("\n", " ")    # Remove newline characters

        # Remove punctuation (except for sentence delimiters if you want)
        sentence = re.sub(r'[^\w\s]', '', sentence)

        # Normalize text (if needed, e.g., lowercasing)
        sentence = sentence.lower()  # Depending on the case-sensitivity of your use case

        # Append the cleaned sentence
        preprocessed_sentences.append(sentence.strip())

    return preprocessed_sentences

# Preprocess the tokenized sentences
preprocessed_sentences = preprocess_punjabi_text(sentences)

print(preprocessed_sentences[:5])  # Print the first few preprocessed sentences
# Out:
# ['ਦ ਨਗਰਨ ਹਠ ਤਆਰ ਕਤ ਗਆ ਸਬਜਆ ਦ ਕਸਤ ਲਈ ਸਫਰਸ2021 ਦ ਕਤਬ ਨਰਦਸਕ ਖਜ ਪਜਬ ਐਗਰਕਲਚਰਲ ਯਨਵਰਸਟ ਲਧਆਣ ਦ ਸਹਇਤ ਨਲ ਵਖ ਵਖ ਵਭਗ ਦ ਮਹਰ ਦਆਰ ਪਰਵਣਤ ਸਫਰਸ ਅਨਸਰ ਤਆਰ ਕਤ ਗਈ ਹ', 'ਇਸ ਪਸਤਕ ਵਚ ਸਬਜਆ ਦ ਵਧਰ ਝੜ ਪਰਪਤ ਕਰਨ ਲਈ 7 ਜਨਵਰ 2021 ਸਰਦਆ ਅਤ 6 ਜਲਈ 2021 ਗਰਮਆ ਨ ਖਜ ਵਗਆਨਆ ਅਤ ਪਸਰ ਮਹਰ ਦ ਬਗਬਨ ਦ ਵਰਚਅਲ ਵਰਕਸਪ ਦਰਨ ਵਚਰ ਗਏ ਨਵ ਢਗ ਦ ਵਰਵ ਦਤ ਗਆ ਹ', 'ਇਹ ਕਤਬ ਬਹਤ ਸਰਲ ਤ ਸਦ ਭਸ ਵਚ ਲਖ ਗਈ ਹ ਤ ਕ ਪਜਬ ਦ ਕਸਨ ਅਤ ਪਸਰ ਸਖਆ ਕਮ ਇਸ ਤ ਵਧ ਤ ਵਧ ਲਭ ਉਠ ਸਕਣ', '15੩੧4 9788193277898 ਕਮਤ  50 ਰਪਏ ਇਹ ਕਤਬ ਕਪ ਰਈਟ ਸਰਖਅਤ ਹ', 'ਪਕਸਕਸਪਦਕ ਦ ਪਰਵਨਗ ਬਨ ਪਰਕਸਤ ਕਰਨ ਦ ਆਗਆ ਨਹ ਹ']

# %%
# !pip install transformers[sentencepiece]

# %%
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 2.0 MB/s eta 0:00:0000:0100:01m
# ...

# %%
from sentence_transformers import SentenceTransformer
model_name = "ai4bharat/indic-bert"
model = SentenceTransformer(model_name)
# Out:
# config.json:   0%|          | 0.00/507 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/135M [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/5.65M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# !pip install datasets
# !pip install faiss-cpu
# !pip install faiss-gpu
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 46.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 17.2 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# from sentence_transformers import CrossEncoder, SentenceTransformer, util
# import torch
# from transformers import RagTokenizer, RagRetriever, RagTokenForGeneration


# # Encode the Punjabi text into embeddings
# corpus_embeddings = model.encode(preprocessed_sentences, convert_to_tensor=True)

# # Load the RAG model and tokenizer
# tokenizer = RagTokenizer.from_pretrained("facebook/rag-token-base")
# retriever = RagRetriever.from_pretrained("facebook/rag-token-base", use_dummy_dataset=True)
# rag_model = RagTokenForGeneration.from_pretrained("facebook/rag-token-base", retriever=retriever)

# # Now you can use this model for QA
# def answer_question(question):
#     input_ids = tokenizer(question, return_tensors="pt").input_ids
#     outputs = rag_model.generate(input_ids)
#     answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
#     return answer

# # Example: Test with a question
# question = "ਪੰਜਾਬ ਵਿਚ ਕੌਣ ਕੌਣ ਜਿਹੇ ਸਬਜ਼ੀਆਂ ਦੀ ਕਾਸ਼ਤ ਹੁੰਦੀ ਹੈ?"
# answer = answer_question(question)
# print(f"Question: {question}")
# print(f"Answer: {answer}")

# %%
from sentence_transformers import SentenceTransformer

# Load the pre-trained Punjabi word embeddings
model_name = "ai4bharat/indic-bert"
embedding_model = SentenceTransformer(model_name)

# Encode the sentences
sentence_embeddings = embedding_model.encode(sentences)
# Out:
# Batches:   0%|          | 0/98 [00:00<?, ?it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def retrieve_similar_sentences(query, sentence_embeddings, sentences, top_n=8):
    query_embedding = embedding_model.encode([query])
    similarities = cosine_similarity(query_embedding, sentence_embeddings)[0]
    top_indices = np.argsort(similarities)[-top_n:][::-1]
    return [sentences[i] for i in top_indices]

# Example query
query = "ਕ੍ਰਿਸ਼ੀ ਵਿੱਚ ਉੱਚਤਮ ਯੂਗਾਂਦਾ ਦੀ ਵਰਤੋਂ"
retrieved_sentences = retrieve_similar_sentences(query, sentence_embeddings, sentences)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
retrieved_sentences
# Out:
# ['ਪੂਸਾ ਹਿਮਾਨੀ (1995) : ਇਹ ਠੰਢੇ ਇਲਾਕੇ ਦੀ ਕਿਸਮ ਹੈ ਅਤੇ ਜਨਵਰੀ\nਦੇ ਦੂਜੇ ਪੰਦਰ੍ਹਵਾੜੇ ਵਿੱਚ ਬਿਜਾਈ ਲਈ ਢੁਕਵੀਂ ਹੈ ।',
#  'ਉ) ਕੇਵਲ ਪੁਮਾਣਿਤ ਕਿਸਮਾਂ ਦਾ ਰੋਗ ਰਹਿਤ ਬੀਜ\nਰੱਖਣਾ ਚਾਹੀਦਾ ਹੈ ।',
#  'ਸੁੱਕੀਆਂ\nਮਿਰਚਾਂ ਵਿਚ ਕੁੜੱਤਣ ਦੇ ਤੱਤ ਦੀ ਮਾਤਰਾ 0.80 ਪ੍ਰਤੀਸ਼ਤ ਹੈ ।',
#  'ਸਿੰਚਾਈ : ਜੇ ਸੰਭਵ ਹੋਵੇ ਤਾਂ ਪੌਲੀਨੈਂਟ ਹਾਊਸ ਜਾਂ ਪੌਲੀ ਹਾਊਸ ਵਿੱਚ\nਤੁਪਕਾ ਸਿੰਚਾਈ ਦੇ ਪ੍ਰਬੰਧ ਨੂੰ ਪਹਿਲ ਦਿਉ ।',
#  'ਇਸ ਸੋਲਰ ਡਰਾਇਅਰ ਵਿੱਚ ਸੁੱਕੇ ਉਤਪਾਦ ਦੀ\nਗੁਣਵੱਤਾ ਬਾਹਰ ਧੁੱਪ ਵਿੱਚ ਸੁੱਕੀ ਜਿਣਸ ਨਾਲੋਂ ਬਿਹਤਰ ਹੁੰਦੀ ਹੈ।',
#  'ਬੀਜ ਵਾਲੀ ਫ਼ਸਲ ਦੀ ਬਿਜਾਈ ਨਵੰਬਰ ਦੇ ਦੂਜੇ ਪੰਦਰ੍ਹਵਾੜੇ ਵਿੱਚ\nਕਰੋ ।',
#  'ਇਸਦੀ\nਅਗੇਤੀ ਪੈਦਾਵਾਰ ਲਈ ਰੇਤਲੀ ਮੈਰਾ ਜ਼ਮੀਨ ਉੱਤਮ ਹੈ ਪਰ ਜ਼ਿਆਦਾ ਪੈਦਾਵਾਰ\nਲੈਣ ਲਈ ਮੈਰਾ ਜ਼ਮੀਨ ਜਿਸ ਵਿੱਚ ਜੀਵਕ ਮਾਦਾ ਕਾਫ਼ੀ ਹੋਵੇ, ਵਧੀਆ ਮੰਨੀ\nਜਾਂਦੀ ਹੈ ।',
#  'ਏ) ਤੇਲੇ ਦੀ ਰੋਕਥਾਮ ਲਈ ਸਿਫ਼ਾਰਸ਼\nਕੀਤੀਆਂ ਦਵਾਈਆਂ ਦਾ ਛਿੜਕਾਅ ਕਰੋ।']

# %%
from huggingface_hub import login

# Log in using your Hugging Face token

TOKEN="token" # Your hugging face token
login(token=f"{TOKEN}")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# from transformers import AutoTokenizer, AutoModelForCausalLM

# # Load Mistral model
# mistral_model_name = "mistralai/Mistral-7B-v0.1"
# tokenizer = AutoTokenizer.from_pretrained(mistral_model_name)
# model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-v0.1")

# # Concatenate retrieved sentences and use them as context for generation
# context = " ".join(retrieved_sentences)
# input_text = f"ਸਵਾਲ: {query}\nਪੱਛੋਕੜ: {context}\nਜਵਾਬ:"

# # Encode input
# input_ids = tokenizer.encode(input_text, return_tensors="pt")

# # Generate answer
# output_ids = model.generate(input_ids, max_length=100)
# answer = tokenizer.decode(output_ids[0], skip_special_tokens=True)

# print("ਜਵਾਬ:", answer)

# %%
# from transformers import AutoTokenizer, AutoModelForCausalLM
# import torch

# # Load Mistral model with FP16 precision
# mistral_model_name = "mistralai/Mistral-7B-v0.1"
# tokenizer = AutoTokenizer.from_pretrained(mistral_model_name)

# # Load the model with half-precision (FP16) if GPU is available
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = AutoModelForCausalLM.from_pretrained(
#     mistral_model_name,
#     torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
# ).to(device)

# # Concatenate retrieved sentences and use them as context for generation
# context = " ".join(retrieved_sentences)
# input_text = f"ਸਵਾਲ: {query}\nਪੱਛੋਕੜ: {context}\nਜਵਾਬ:"

# # Encode input
# input_ids = tokenizer.encode(input_text, return_tensors="pt").to(device)

# # Generate answer with optimized parameters
# output_ids = model.generate(input_ids, max_length=100, temperature=0.7)

# # Decode the output
# answer = tokenizer.decode(output_ids[0], skip_special_tokens=True)

# print("ਜਵਾਬ:", answer)

# %%
retrieved_sentences
# Out:
# ['ਪੂਸਾ ਹਿਮਾਨੀ (1995) : ਇਹ ਠੰਢੇ ਇਲਾਕੇ ਦੀ ਕਿਸਮ ਹੈ ਅਤੇ ਜਨਵਰੀ\nਦੇ ਦੂਜੇ ਪੰਦਰ੍ਹਵਾੜੇ ਵਿੱਚ ਬਿਜਾਈ ਲਈ ਢੁਕਵੀਂ ਹੈ ।',
#  'ਉ) ਕੇਵਲ ਪੁਮਾਣਿਤ ਕਿਸਮਾਂ ਦਾ ਰੋਗ ਰਹਿਤ ਬੀਜ\nਰੱਖਣਾ ਚਾਹੀਦਾ ਹੈ ।',
#  'ਸੁੱਕੀਆਂ\nਮਿਰਚਾਂ ਵਿਚ ਕੁੜੱਤਣ ਦੇ ਤੱਤ ਦੀ ਮਾਤਰਾ 0.80 ਪ੍ਰਤੀਸ਼ਤ ਹੈ ।',
#  'ਸਿੰਚਾਈ : ਜੇ ਸੰਭਵ ਹੋਵੇ ਤਾਂ ਪੌਲੀਨੈਂਟ ਹਾਊਸ ਜਾਂ ਪੌਲੀ ਹਾਊਸ ਵਿੱਚ\nਤੁਪਕਾ ਸਿੰਚਾਈ ਦੇ ਪ੍ਰਬੰਧ ਨੂੰ ਪਹਿਲ ਦਿਉ ।',
#  'ਇਸ ਸੋਲਰ ਡਰਾਇਅਰ ਵਿੱਚ ਸੁੱਕੇ ਉਤਪਾਦ ਦੀ\nਗੁਣਵੱਤਾ ਬਾਹਰ ਧੁੱਪ ਵਿੱਚ ਸੁੱਕੀ ਜਿਣਸ ਨਾਲੋਂ ਬਿਹਤਰ ਹੁੰਦੀ ਹੈ।',
#  'ਬੀਜ ਵਾਲੀ ਫ਼ਸਲ ਦੀ ਬਿਜਾਈ ਨਵੰਬਰ ਦੇ ਦੂਜੇ ਪੰਦਰ੍ਹਵਾੜੇ ਵਿੱਚ\nਕਰੋ ।',
#  'ਇਸਦੀ\nਅਗੇਤੀ ਪੈਦਾਵਾਰ ਲਈ ਰੇਤਲੀ ਮੈਰਾ ਜ਼ਮੀਨ ਉੱਤਮ ਹੈ ਪਰ ਜ਼ਿਆਦਾ ਪੈਦਾਵਾਰ\nਲੈਣ ਲਈ ਮੈਰਾ ਜ਼ਮੀਨ ਜਿਸ ਵਿੱਚ ਜੀਵਕ ਮਾਦਾ ਕਾਫ਼ੀ ਹੋਵੇ, ਵਧੀਆ ਮੰਨੀ\nਜਾਂਦੀ ਹੈ ।',
#  'ਏ) ਤੇਲੇ ਦੀ ਰੋਕਥਾਮ ਲਈ ਸਿਫ਼ਾਰਸ਼\nਕੀਤੀਆਂ ਦਵਾਈਆਂ ਦਾ ਛਿੜਕਾਅ ਕਰੋ।']

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Load Mistral model with FP16 precision
mistral_model_name = "mistralai/Mistral-7B-v0.1"
tokenizer = AutoTokenizer.from_pretrained(mistral_model_name)

# Load the model with half-precision (FP16) if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutoModelForCausalLM.from_pretrained(
    mistral_model_name,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
).to(device)

# Concatenate retrieved sentences and use them as context for generation
context = " ".join(retrieved_sentences)
input_text = f"ਸਵਾਲ: {query}\nਪੱਛੋਕੜ: {context}\nਜਵਾਬ:"

# Encode input with attention mask
input_ids = tokenizer.encode(input_text, return_tensors="pt").to(device)
attention_mask = torch.ones(input_ids.shape, device=device)

# Generate answer with optimized parameters
output_ids = model.generate(
    input_ids, 
    attention_mask=attention_mask,
    max_new_tokens=50,  # Specify the number of new tokens to generate
    do_sample=True,     # Enable sampling to use temperature
    temperature=0.7     # Control the randomness of sampling
)

# Decode the output
answer = tokenizer.decode(output_ids[0], skip_special_tokens=True)

print("ਜਵਾਬ:", answer)
# Out:
# tokenizer_config.json:   0%|          | 0.00/996 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ਜਵਾਬ: ਸਵਾਲ: ਕ੍ਰਿਸ਼ੀ ਵਿੱਚ ਉੱਚਤਮ ਯੂਗਾਂਦਾ ਦੀ ਵਰਤੋਂ
# ਪੱਛੋਕੜ: ਪੂਸਾ ਹਿਮਾਨੀ (1995) : ਇਹ ਠੰਢੇ ਇਲਾਕੇ ਦੀ ਕਿਸਮ ਹੈ ਅਤੇ ਜਨਵਰੀ
# ਦੇ ਦੂਜੇ ਪੰਦਰ੍ਹਵਾੜੇ ਵਿੱਚ ਬਿਜਾਈ ਲਈ ਢੁਕਵੀਂ ਹੈ । ਉ) ਕੇਵਲ ਪੁਮਾਣਿਤ ਕਿਸਮਾਂ ਦਾ ਰੋਗ ਰਹਿਤ ਬੀਜ
# ਰੱਖਣਾ ਚਾਹੀਦਾ ਹੈ । ਸੁੱਕੀਆਂ
# ...

# %%
# !pip install transformers accelerate bitsandbytes

# %%
# !pip install -U bitsandbytes

# %%
# from transformers import AutoTokenizer, AutoModelForCausalLM
# # Define a directory to save the model and tokenizer
# save_directory = "./saved_mistral_model"

# # Save the tokenizer
# tokenizer.save_pretrained(save_directory)

# # Save the model
# model.save_pretrained(save_directory)

# print(f"Model and tokenizer have been saved to '{save_directory}'.")

# %%
# import joblib
# joblib.dump(model, '/kaggle/working/model.pkl')

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# # Define the directory where the model and tokenizer are saved
# save_directory = "./saved_mistral_model"

# # Load the tokenizer
# tokenizer = AutoTokenizer.from_pretrained(save_directory)

# Load the model with the appropriate precision
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = AutoModelForCausalLM.from_pretrained(
#     save_directory,
#     torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
# ).to(device)

def generate_answer(query, retrieved_sentences, max_new_tokens=50, temperature=0.7):
    """
    Generates an answer based on the query and retrieved context sentences.

    Args:
        query (str): The user's question.
        retrieved_sentences (list of str): List of context sentences retrieved relevant to the query.
        max_new_tokens (int, optional): Maximum number of tokens to generate. Defaults to 50.
        temperature (float, optional): Sampling temperature. Higher values mean more randomness. Defaults to 0.7.

    Returns:
        str: The generated answer.
    """
    # Concatenate retrieved sentences to form the context
    context = " ".join(retrieved_sentences)
    
    # Create the input text
    input_text = f"ਸਵਾਲ: {query}\nਪੱਛੋਕੜ: {context}\nਜਵਾਬ:"
    
    # Encode input with attention mask
    input_ids = tokenizer.encode(input_text, return_tensors="pt").to(device)
    attention_mask = torch.ones(input_ids.shape, device=device)
    
    # Generate answer
    output_ids = model.generate(
        input_ids, 
        attention_mask=attention_mask,
        max_new_tokens=max_new_tokens,  # Number of tokens to generate
        do_sample=True,                 # Enable sampling to use temperature
        temperature=temperature         # Control the randomness of sampling
    )
    
    # Decode the output
    answer = tokenizer.decode(output_ids[0], skip_special_tokens=True)
    
    # Extract the answer part after the prompt
    # Assuming the answer starts after "ਜਵਾਬ:"
    try:
        answer = answer.split("ਜਵਾਬ:")[-1].strip()
    except:
        pass  # In case the split doesn't work as expected
    
    return answer

# Example usage:
if __name__ == "__main__":
    user_query = "ਬੀਜ ਪੈਦਾ ਕਰਨ ਲਈ ਫ਼ਸਲ ਦੇ ਖੇਤ ਦੀ ਦੂਰੀ ਦੂਸਰੀਆਂ ਕਿਸਮਾਂ ਵਾਲੀਆਂ ਫ਼ਸਲਾਂ ਤੋਂ ਕਿੰਨੀ ਹੋਣੀ ਚਾਹੀਦੀ ਹੈ?"
    user_retrieved_sentences=retrieve_similar_sentences(user_query, sentence_embeddings, sentences)
    
    response = generate_answer(user_query, user_retrieved_sentences)
    print("ਜਵਾਬ:", response)

# %%
# !rm -rf /kaggle/working/*
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
q="ਬੀਜ ਪੈਦਾ ਕਰਨ ਲਈ ਫ਼ਸਲ ਦੇ ਖੇਤ ਦੀ ਦੂਰੀ ਦੂਸਰੀਆਂ ਕਿਸਮਾਂ ਵਾਲੀਆਂ ਫ਼ਸਲਾਂ ਤੋਂ ਕਿੰਨੀ ਹੋਣੀ ਚਾਹੀਦੀ ਹੈ?"
retrieve_similar_sentences(q, sentence_embeddings, sentences)

# %%
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# .  ..  .virtual_documents

# %%
import shutil
model.save_pretrained("/kaggle/working/mistral_model")
shutil.make_archive("/kaggle/working/mistral_model", 'zip', "/kaggle/working/mistral_model")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/conda/lib/python3.10/zipfile.py:1788, in ZipFile.write(self, filename, arcname, compress_type, compresslevel)
#    1787 with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1788     shutil.copyfileobj(src, dest, 1024*8)
#
# File /opt/conda/lib/python3.10/shutil.py:198, in copyfileobj(fsrc, fdst, length)
#     197     break
# --> 198 fdst_write(buf)
#
# File /opt/conda/lib/python3.10/zipfile.py:1143, in _ZipWriteFile.write(self, data)
#    1142     self._compress_size += len(data)
# -> 1143 self._fileobj.write(data)
#    1144 return nbytes
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ...

# %%
import torch
import pickle
from transformers import AutoTokenizer, AutoModelForCausalLM

# Save the model
model_save_path = "mistral_model.pth"
torch.save(model.state_dict(), model_save_path)

# %%
print(f"Model saved: {model_save_path}")
# Out:
# Model saved: mistral_model.pth
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 print(f"Model saved: {model_save_path}")
# ----> 2 FileLink(model_save_path)
#
# NameError: name 'FileLink' is not defined

# %%
from IPython.display import FileLink
FileLink(model_save_path)
# Out:
# /kaggle/working/mistral_model.pth

# %%
# Save the tokenizer
tokenizer_save_path = "mistral_tokenizer.pkl"
with open(tokenizer_save_path, 'wb') as f:
    pickle.dump(tokenizer, f)

# If you're on Kaggle, download these files
from IPython.display import FileLink

# Provide download links

print(f"Tokenizer saved: {tokenizer_save_path}")

FileLink(tokenizer_save_path)
# Out:
# Tokenizer saved: mistral_tokenizer.pkl
# /kaggle/working/mistral_tokenizer.pkl

# %%
import shutil

# Zip the saved model and tokenizer directories

tokenizer.save_pretrained("/kaggle/working/mistral_tokenizer")
shutil.make_archive("/kaggle/working/mistral_tokenizer", 'zip', "/kaggle/working/mistral_tokenizer")
