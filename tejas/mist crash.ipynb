# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the data
file_path = "../static/1.txt"  # Update with the actual path to your file in Google Drive
with open(file_path, 'r', encoding='utf-8') as file:
    punjabi_text = file.read()

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /Users/pratham/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Simple heuristic-based tokenizer for Punjabi text
def punjabi_sent_tokenize(text):
    sentences = text.split('।')  # Use the appropriate sentence delimiter
    return [sentence.strip() for sentence in sentences if sentence]

# Apply the custom tokenizer
sentences = punjabi_sent_tokenize(punjabi_text)

print(sentences[:5])  # Print the first few tokenized sentences
# Out:
# ["ਦੀ ਨਿਗਰਾਨੀ ਹੇਠ ਤਿਆਰ ਕੀਤਾ ਗਿਆ\n\n“ਸਬਜ਼ੀਆਂ ਦੀ ਕਾਸ਼ਤ ਲਈ ਸਿਫ਼ਾਰਸ਼ਾਂ-2021', ਦੀ ਕਿਤਾਬ ਨਿਰਦੇਸ਼ਕ\nਖੋਜ, ਪੰਜਾਬ ਐਗਰੀਕਲਚਰਲ ਯੂਨੀਵਰਸਿਟੀ, ਲੁਧਿਆਣਾ ਦੀ ਸਹਾਇਤਾ ਨਾਲ ਵੱਖ-\nਵੱਖ ਵਿਭਾਗਾਂ ਦੇ ਮਾਹਿਰਾਂ ਦੁਆਰਾ ਪ੍ਰਵਾਣਿਤ ਸਿਫ਼ਾਰਸ਼ਾਂ ਅਨੁਸਾਰ ਤਿਆਰ ਕੀਤੀ ਗਈ\nਹੈ", "ਇਸ ਪੁਸਤਕ ਵਿੱਚ ਸਬਜ਼ੀਆਂ ਦਾ ਵਧੇਰੇ ਝਾੜ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ 7 ਜਨਵਰੀ\n2021 (ਸਰਦੀਆਂ) ਅਤੇ 6 ਜੁਲਾਈ 2021 (ਗਰਮੀਆਂ) ਨੂੰ 'ਖੋਜ ਵਿਗਿਆਨੀਆਂ ਅਤੇ\nਪਸਾਰ ਮਾਹਿਰਾਂ ਦੀ ਬਾਗਬਾਨੀ ਦੇ ਵਰਚੁਅਲ ਵਰਕਸ਼ਾਪਾਂ` ਦੌਰਾਨ ਵਿਚਾਰੇ ਗਏ ਨਵੇ\nਢੰਗਾਂ ਦਾ ਵੇਰਵਾ ਦਿੱਤਾ ਗਿਆ ਹੈ", 'ਇਹ ਕਿਤਾਬ ਬਹੁਤ ਸਰਲ ਤੇ ਸਾਦੀ ਭਾਸ਼ਾ ਵਿੱਚ\nਲਿਖੀ ਗਈ ਹੈ ਤਾਂ ਕਿ ਪੰਜਾਬ ਦੇ ਕਿਸਾਨ ਅਤੇ ਪਸਾਰ ਸਿੱਖਿਆ ਕਾਮੇ ਇਸ ਤੋਂ ਵੱਧ ਤੋਂ\nਵੱਧ ਲਾਭ ਉਠਾ ਸਕਣ', '15੩੧4 978-81-932778-9-8\n\nਕੀਮਤ : 50 ਰੁਪਏ\n\nਇਹ ਕਿਤਾਬ ਕਾਪੀ ਰਾਈਟ ਸੁਰੱਖਿਅਤ ਹੈ', 'ਪੁਕਾਸ਼ਕ/ਸੰਪਾਦਕ ਦੀ ਪ੍ਰਵਾਨਗੀ\nਬਿਨਾਂ ਪ੍ਰਕਾਸ਼ਤ ਕਰਨ ਦੀ ਆਗਿਆ ਨਹੀਂ ਹੈ']

# %%
# !pip install indic-nlp-library
# Out:
# Requirement already satisfied: indic-nlp-library in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (0.92)
# Requirement already satisfied: sphinx-argparse in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from indic-nlp-library) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from indic-nlp-library) (2.0.0)
# Requirement already satisfied: morfessor in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from indic-nlp-library) (2.2.2)
# Requirement already satisfied: numpy in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from pandas->indic-nlp-library) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from pandas->indic-nlp-library) (2024.1)
# Requirement already satisfied: sphinx>=5.1.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx-argparse->indic-nlp-library) (7.4.7)
# Requirement already satisfied: docutils>=0.19 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx-argparse->indic-nlp-library) (0.20.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx-rtd-theme->indic-nlp-library) (4.1)
# Requirement already satisfied: six>=1.5 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.4)
# Requirement already satisfied: Pygments>=2.17 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.18.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.15.0)
# Requirement already satisfied: alabaster~=0.7.14 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.3)
# Requirement already satisfied: packaging>=23.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (24.1)
# Requirement already satisfied: tomli>=2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2024.7.4)

# %%
from indicnlp.tokenize.sentence_tokenize import sentence_split

# Apply the sentence tokenizer from Indic NLP
sentences = sentence_split(punjabi_text, lang='pa')  # 'pa' is the language code for Punjabi

print(sentences[:5])  # Print the first few tokenized sentences
# Out:
# ["ਦੀ ਨਿਗਰਾਨੀ ਹੇਠ ਤਿਆਰ ਕੀਤਾ ਗਿਆ\n\n“ਸਬਜ਼ੀਆਂ ਦੀ ਕਾਸ਼ਤ ਲਈ ਸਿਫ਼ਾਰਸ਼ਾਂ-2021', ਦੀ ਕਿਤਾਬ ਨਿਰਦੇਸ਼ਕ\nਖੋਜ, ਪੰਜਾਬ ਐਗਰੀਕਲਚਰਲ ਯੂਨੀਵਰਸਿਟੀ, ਲੁਧਿਆਣਾ ਦੀ ਸਹਾਇਤਾ ਨਾਲ ਵੱਖ-\nਵੱਖ ਵਿਭਾਗਾਂ ਦੇ ਮਾਹਿਰਾਂ ਦੁਆਰਾ ਪ੍ਰਵਾਣਿਤ ਸਿਫ਼ਾਰਸ਼ਾਂ ਅਨੁਸਾਰ ਤਿਆਰ ਕੀਤੀ ਗਈ\nਹੈ।", "ਇਸ ਪੁਸਤਕ ਵਿੱਚ ਸਬਜ਼ੀਆਂ ਦਾ ਵਧੇਰੇ ਝਾੜ ਪ੍ਰਾਪਤ ਕਰਨ ਲਈ 7 ਜਨਵਰੀ\n2021 (ਸਰਦੀਆਂ) ਅਤੇ 6 ਜੁਲਾਈ 2021 (ਗਰਮੀਆਂ) ਨੂੰ 'ਖੋਜ ਵਿਗਿਆਨੀਆਂ ਅਤੇ\nਪਸਾਰ ਮਾਹਿਰਾਂ ਦੀ ਬਾਗਬਾਨੀ ਦੇ ਵਰਚੁਅਲ ਵਰਕਸ਼ਾਪਾਂ` ਦੌਰਾਨ ਵਿਚਾਰੇ ਗਏ ਨਵੇ\nਢੰਗਾਂ ਦਾ ਵੇਰਵਾ ਦਿੱਤਾ ਗਿਆ ਹੈ।", 'ਇਹ ਕਿਤਾਬ ਬਹੁਤ ਸਰਲ ਤੇ ਸਾਦੀ ਭਾਸ਼ਾ ਵਿੱਚ\nਲਿਖੀ ਗਈ ਹੈ ਤਾਂ ਕਿ ਪੰਜਾਬ ਦੇ ਕਿਸਾਨ ਅਤੇ ਪਸਾਰ ਸਿੱਖਿਆ ਕਾਮੇ ਇਸ ਤੋਂ ਵੱਧ ਤੋਂ\nਵੱਧ ਲਾਭ ਉਠਾ ਸਕਣ।', '15੩੧4 978-81-932778-9-8\n\nਕੀਮਤ : 50 ਰੁਪਏ\n\nਇਹ ਕਿਤਾਬ ਕਾਪੀ ਰਾਈਟ ਸੁਰੱਖਿਅਤ ਹੈ ।', 'ਪੁਕਾਸ਼ਕ/ਸੰਪਾਦਕ ਦੀ ਪ੍ਰਵਾਨਗੀ\nਬਿਨਾਂ ਪ੍ਰਕਾਸ਼ਤ ਕਰਨ ਦੀ ਆਗਿਆ ਨਹੀਂ ਹੈ ।']

# %%
import re

def preprocess_punjabi_text(sentences):
    preprocessed_sentences = []
    for sentence in sentences:
        # Remove unwanted characters like newlines and multiple spaces
        sentence = re.sub(r'\s+', ' ', sentence)  # Replace multiple spaces/newlines with a single space
        sentence = sentence.replace("\n", " ")    # Remove newline characters

        # Remove punctuation (except for sentence delimiters if you want)
        sentence = re.sub(r'[^\w\s]', '', sentence)

        # Normalize text (if needed, e.g., lowercasing)
        sentence = sentence.lower()  # Depending on the case-sensitivity of your use case

        # Append the cleaned sentence
        preprocessed_sentences.append(sentence.strip())

    return preprocessed_sentences

# Preprocess the tokenized sentences
preprocessed_sentences = preprocess_punjabi_text(sentences)

print(preprocessed_sentences[:5])  # Print the first few preprocessed sentences
# Out:
# ['ਦ ਨਗਰਨ ਹਠ ਤਆਰ ਕਤ ਗਆ ਸਬਜਆ ਦ ਕਸਤ ਲਈ ਸਫਰਸ2021 ਦ ਕਤਬ ਨਰਦਸਕ ਖਜ ਪਜਬ ਐਗਰਕਲਚਰਲ ਯਨਵਰਸਟ ਲਧਆਣ ਦ ਸਹਇਤ ਨਲ ਵਖ ਵਖ ਵਭਗ ਦ ਮਹਰ ਦਆਰ ਪਰਵਣਤ ਸਫਰਸ ਅਨਸਰ ਤਆਰ ਕਤ ਗਈ ਹ', 'ਇਸ ਪਸਤਕ ਵਚ ਸਬਜਆ ਦ ਵਧਰ ਝੜ ਪਰਪਤ ਕਰਨ ਲਈ 7 ਜਨਵਰ 2021 ਸਰਦਆ ਅਤ 6 ਜਲਈ 2021 ਗਰਮਆ ਨ ਖਜ ਵਗਆਨਆ ਅਤ ਪਸਰ ਮਹਰ ਦ ਬਗਬਨ ਦ ਵਰਚਅਲ ਵਰਕਸਪ ਦਰਨ ਵਚਰ ਗਏ ਨਵ ਢਗ ਦ ਵਰਵ ਦਤ ਗਆ ਹ', 'ਇਹ ਕਤਬ ਬਹਤ ਸਰਲ ਤ ਸਦ ਭਸ ਵਚ ਲਖ ਗਈ ਹ ਤ ਕ ਪਜਬ ਦ ਕਸਨ ਅਤ ਪਸਰ ਸਖਆ ਕਮ ਇਸ ਤ ਵਧ ਤ ਵਧ ਲਭ ਉਠ ਸਕਣ', '15੩੧4 9788193277898 ਕਮਤ  50 ਰਪਏ ਇਹ ਕਤਬ ਕਪ ਰਈਟ ਸਰਖਅਤ ਹ', 'ਪਕਸਕਸਪਦਕ ਦ ਪਰਵਨਗ ਬਨ ਪਰਕਸਤ ਕਰਨ ਦ ਆਗਆ ਨਹ ਹ']

# %%
from sentence_transformers import CrossEncoder, SentenceTransformer, util
import torch
from transformers import RagTokenizer, RagRetriever, RagTokenForGeneration

# Load the pretrained sentence-transformer model
model_name = "ai4bharat/indic-bert"
model = SentenceTransformer(model_name)

# Encode the Punjabi text into embeddings
corpus_embeddings = model.encode(preprocessed_sentences, convert_to_tensor=True)

# Load the RAG model and tokenizer
tokenizer = RagTokenizer.from_pretrained("facebook/rag-token-base")
retriever = RagRetriever.from_pretrained("facebook/rag-token-base", use_dummy_dataset=True)
rag_model = RagTokenForGeneration.from_pretrained("facebook/rag-token-base", retriever=retriever)

# Now you can use this model for QA
def answer_question(question):
    input_ids = tokenizer(question, return_tensors="pt").input_ids
    outputs = rag_model.generate(input_ids)
    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer

# Example: Test with a question
question = "ਪੰਜਾਬ ਵਿਚ ਕੌਣ ਕੌਣ ਜਿਹੇ ਸਬਜ਼ੀਆਂ ਦੀ ਕਾਸ਼ਤ ਹੁੰਦੀ ਹੈ?"
answer = answer_question(question)
print(f"Question: {question}")
print(f"Answer: {answer}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-c63502983386> in <cell line: 1>()
# ----> 1 from sentence_transformers import CrossEncoder, SentenceTransformer, util
#       2 import torch
#       3 from transformers import RagTokenizer, RagRetriever, RagTokenForGeneration
#       4
#       5 # Load the pretrained sentence-transformer model
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install transformers[sentencepiece]
# Out:
# zsh:1: no matches found: transformers[sentencepiece]

# %%
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: sentence_transformers in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sentence_transformers) (4.44.2)
# Requirement already satisfied: tqdm in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sentence_transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sentence_transformers) (2.2.2)
# Requirement already satisfied: numpy in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sentence_transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sentence_transformers) (1.5.1)
# Requirement already satisfied: scipy in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sentence_transformers) (1.14.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sentence_transformers) (0.24.5)
# Requirement already satisfied: Pillow in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sentence_transformers) (10.4.0)
# Requirement already satisfied: filelock in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.2)
# Requirement already satisfied: networkx in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)

# %%
from sentence_transformers import SentenceTransformer
model_name = "ai4bharat/indic-bert"
model = SentenceTransformer(model_name)
# Out:
# /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# No sentence-transformers model found with name ai4bharat/indic-bert. Creating a new one with mean pooling.
# /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# !pip install datasets
# !pip install faiss-cpu
# !pip install faiss-gpu
# Out:
# Requirement already satisfied: datasets in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (2.21.0)
# Requirement already satisfied: filelock in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (3.10.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (0.24.5)
# Requirement already satisfied: packaging in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from aiohttp->datasets) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0.post1-cp310-cp310-macosx_10_14_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy<2.0,>=1.0 in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /Users/pratham/miniconda3/envs/ocr/lib/python3.10/site-packages (from faiss-cpu) (24.1)
# Downloading faiss_cpu-1.8.0.post1-cp310-cp310-macosx_10_14_x86_64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 196.7 kB/s eta 0:00:00a 0:00:02
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0.post1
# ERROR: Could not find a version that satisfies the requirement faiss-gpu (from versions: none)
# ERROR: No matching distribution found for faiss-gpu

# %%
from sentence_transformers import CrossEncoder, SentenceTransformer, util
import torch
from transformers import RagTokenizer, RagRetriever, RagTokenForGeneration


# Encode the Punjabi text into embeddings
corpus_embeddings = model.encode(preprocessed_sentences, convert_to_tensor=True)

# Load the RAG model and tokenizer
tokenizer = RagTokenizer.from_pretrained("facebook/rag-token-base")
retriever = RagRetriever.from_pretrained("facebook/rag-token-base", use_dummy_dataset=True)
rag_model = RagTokenForGeneration.from_pretrained("facebook/rag-token-base", retriever=retriever)

# Now you can use this model for QA
def answer_question(question):
    input_ids = tokenizer(question, return_tensors="pt").input_ids
    outputs = rag_model.generate(input_ids)
    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer

# Example: Test with a question
question = "ਪੰਜਾਬ ਵਿਚ ਕੌਣ ਕੌਣ ਜਿਹੇ ਸਬਜ਼ੀਆਂ ਦੀ ਕਾਸ਼ਤ ਹੁੰਦੀ ਹੈ?"
answer = answer_question(question)
print(f"Question: {question}")
print(f"Answer: {answer}")
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.
# Downloading builder script:   0%|          | 0.00/8.63k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# The repository for wiki_dpr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/wiki_dpr.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data:   0%|          | 0.00/40.8M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/2.06G [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/rag-token-base were not used when initializing RagTokenForGeneration: ['rag.question_encoder.question_encoder.bert_model.pooler.dense.bias', 'rag.question_encoder.question_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing RagTokenForGeneration from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RagTokenForGeneration from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Question: ਪੰਜਾਬ ਵਿਚ ਕੌਣ ਕੌਣ ਜਿਹੇ ਸਬਜ਼ੀਆਂ ਦੀ ਕਾਸ਼ਤ ਹੁੰਦੀ ਹੈ?
# Answer: The?????????????????

# %%
from sentence_transformers import SentenceTransformer

# Load the pre-trained Punjabi word embeddings
model_name = "ai4bharat/indic-bert"
embedding_model = SentenceTransformer(model_name)

# Encode the sentences
sentence_embeddings = embedding_model.encode(sentences)
# Out:
# No sentence-transformers model found with name ai4bharat/indic-bert. Creating a new one with mean pooling.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def retrieve_similar_sentences(query, sentence_embeddings, sentences, top_n=5):
    query_embedding = embedding_model.encode([query])
    similarities = cosine_similarity(query_embedding, sentence_embeddings)[0]
    top_indices = np.argsort(similarities)[-top_n:][::-1]
    return [sentences[i] for i in top_indices]

# Example query
query = "ਕ੍ਰਿਸ਼ੀ ਵਿੱਚ ਉੱਚਤਮ ਯੂਗਾਂਦਾ ਦੀ ਵਰਤੋਂ"
retrieved_sentences = retrieve_similar_sentences(query, sentence_embeddings, sentences)

# %%
retrieved_sentences
# Out:
# ['ਪੂਸਾ ਹਿਮਾਨੀ (1995) : ਇਹ ਠੰਢੇ ਇਲਾਕੇ ਦੀ ਕਿਸਮ ਹੈ ਅਤੇ ਜਨਵਰੀ\nਦੇ ਦੂਜੇ ਪੰਦਰ੍ਹਵਾੜੇ ਵਿੱਚ ਬਿਜਾਈ ਲਈ ਢੁਕਵੀਂ ਹੈ ।',
#  'ਉ) ਕੇਵਲ ਪੁਮਾਣਿਤ ਕਿਸਮਾਂ ਦਾ ਰੋਗ ਰਹਿਤ ਬੀਜ\nਰੱਖਣਾ ਚਾਹੀਦਾ ਹੈ ।',
#  'ਸੁੱਕੀਆਂ\nਮਿਰਚਾਂ ਵਿਚ ਕੁੜੱਤਣ ਦੇ ਤੱਤ ਦੀ ਮਾਤਰਾ 0.80 ਪ੍ਰਤੀਸ਼ਤ ਹੈ ।',
#  'ਸਿੰਚਾਈ : ਜੇ ਸੰਭਵ ਹੋਵੇ ਤਾਂ ਪੌਲੀਨੈਂਟ ਹਾਊਸ ਜਾਂ ਪੌਲੀ ਹਾਊਸ ਵਿੱਚ\nਤੁਪਕਾ ਸਿੰਚਾਈ ਦੇ ਪ੍ਰਬੰਧ ਨੂੰ ਪਹਿਲ ਦਿਉ ।',
#  'ਇਸ ਸੋਲਰ ਡਰਾਇਅਰ ਵਿੱਚ ਸੁੱਕੇ ਉਤਪਾਦ ਦੀ\nਗੁਣਵੱਤਾ ਬਾਹਰ ਧੁੱਪ ਵਿੱਚ ਸੁੱਕੀ ਜਿਣਸ ਨਾਲੋਂ ਬਿਹਤਰ ਹੁੰਦੀ ਹੈ।']

# %%
from huggingface_hub import login

# Log in using your Hugging Face token
login(token="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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /Users/pratham/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load Mistral model
mistral_model_name = "mistralai/Mistral-7B-v0.1"
tokenizer = AutoTokenizer.from_pretrained(mistral_model_name)
model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-v0.1")

# Concatenate retrieved sentences and use them as context for generation
context = " ".join(retrieved_sentences)
input_text = f"ਸਵਾਲ: {query}\nਪੱਛੋਕੜ: {context}\nਜਵਾਬ:"

# Encode input
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Generate answer
output_ids = model.generate(input_ids, max_length=100)
answer = tokenizer.decode(output_ids[0], skip_special_tokens=True)

print("ਜਵਾਬ:", answer)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Load Mistral model with FP16 precision
mistral_model_name = "mistralai/Mistral-7B-v0.1"
tokenizer = AutoTokenizer.from_pretrained(mistral_model_name)

# Load the model with half-precision (FP16) if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutoModelForCausalLM.from_pretrained(
    mistral_model_name,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
).to(device)

# Concatenate retrieved sentences and use them as context for generation
context = " ".join(retrieved_sentences)
input_text = f"ਸਵਾਲ: {query}\nਪੱਛੋਕੜ: {context}\nਜਵਾਬ:"

# Encode input with attention mask
input_ids = tokenizer.encode(input_text, return_tensors="pt").to(device)
attention_mask = torch.ones(input_ids.shape, device=device)

# Generate answer with optimized parameters
output_ids = model.generate(
    input_ids, 
    attention_mask=attention_mask,
    max_new_tokens=50,  # Specify the number of new tokens to generate
    do_sample=True,     # Enable sampling to use temperature
    temperature=0.7     # Control the randomness of sampling
)

# Decode the output
answer = tokenizer.decode(output_ids[0], skip_special_tokens=True)

print("ਜਵਾਬ:", answer)
